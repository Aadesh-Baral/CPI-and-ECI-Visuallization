# %%
import pandas as pd

# %%
first=pd.read_excel('EmployeeTotalCompensation_AllCensusRegions_updated.xlsx')

# %%
first
# Out:
#    Employment Cost Index (NAICS)  \
# 0            Original Data Value
# 1                            NaN
# 2                     Series Id:
# 3        Not seasonally adjusted
# 4                  Series Title:
# ..                           ...
# 63                          2019
# 64                          2019
# 65                          2020
# 66                          2020
# 67                          2020
#
#                                            Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                                                 NaN        NaN        NaN
# 1                                                 NaN        NaN        NaN
# 2                                   CIU2010000000230I        NaN        NaN
# 3                                                 NaN        NaN        NaN
# 4   Total compensation for Private industry worker...        NaN        NaN
# ..                                                ...        ...        ...
# ...

# %%
clean=first.dropna()

# %%
clean.columns=['Year','Jan','Feb','Mar','Qtr1','Apr','May','Jun','Qtr2','Jul','Aug','Sep','Qtr3','Oct','Nov','Dec','Qtr4','Annual','HALF1','HALF2']
clean.drop(10,inplace=True)
clean.set_index('Year',inplace=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-57-e04f1e5d628e> in <module>
# ----> 1 clean.columns=['Year','Jan','Feb','Mar','Qtr1','Apr','May','Jun','Qtr2','Jul','Aug','Sep','Qtr3','Oct','Nov','Dec','Qtr4','Annual','HALF1','HALF2']
#       2 clean.drop(10,inplace=True)
#       3 clean.set_index('Year',inplace=True)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    5150         try:
#    5151             object.__getattribute__(self, name)
# -> 5152             return object.__setattr__(self, name, value)
#    5153         except AttributeError:
#    5154             pass
#
# pandas\_libs\properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _set_axis(self, axis, labels)
#     562     def _set_axis(self, axis: int, labels: Index) -> None:
# ...

# %%
clean
# Out:
# Empty DataFrame
# Columns: [Employment Cost Index (NAICS), Unnamed: 1, Unnamed: 2, Unnamed: 3, Unnamed: 4, Unnamed: 5, Unnamed: 6, Unnamed: 7, Unnamed: 8]
# Index: []

# %%
clean.to_csv('NortheastCR_CPI_&_ECI.csv',index=False)
